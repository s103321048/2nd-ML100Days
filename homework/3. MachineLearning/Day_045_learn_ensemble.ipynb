# %%
from IPython.display import Image
Image(filename = "t1.png", width=500)

# %%
Image(filename = "t2.png", width=500)

# %%
Image(filename = "t3.png", width=500)

# %%
Image(filename = "t4_1+2+3.png", width=500)
